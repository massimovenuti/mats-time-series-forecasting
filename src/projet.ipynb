# %%
import torch
import pickle
import numpy as np
import pandas as pd
from copy import deepcopy
from torch import nn
from torch.utils.data import Dataset,DataLoader

# %%
def sauvegardeFichier(nomFichier,obj):
    with open(nomFichier,'wb') as fichier :
        enregistre = pickle.Pickler(fichier)
        enregistre.dump(obj)

def lectureFichier(nomFichier):
    with open(nomFichier,'rb') as fichier :
        recupere = pickle.Unpickler(fichier)
        return recupere.load()

# %%
class DatasetLd(Dataset):
    def __init__(self,path='../data/LD2011_2014/LD2011_2014.pkl',DIM_T=192,DIM_H=96):
        self.data = lectureFichier('../data/LD2011_2014/LD2011_2014.pkl')
        self.DIM_T = DIM_T
        self.DIM_H = DIM_H

    def __len__(self):
        return len(self.data)

    def __getitem__(self, indice):
        X = self.data[indice:indice+self.DIM_T,:]
        y = self.data[indice+self.DIM_T:indice+self.DIM_T+self.DIM_H,:]
        return (X,y)
    
    def __collate_fn__(self,batch):
        X = torch.stack([ torch.tensor(item[0],dtype=torch.float32) for item in batch])
        y = torch.stack([ torch.tensor(item[1],dtype=torch.float32) for item in batch]) 
        return X,y

# %%
BATCH_SIZE = 64
DIM_T = 192 # Longeur d'une serie chronologique stage 1
DIM_H = [96, 192, 336, 720]# Nombre de valeur à prédire pour une serie chronologique

dataset1  = DatasetLd(path='../data/LD2011_2014/LD2011_2014.pkl',DIM_T=DIM_T,DIM_H=DIM_H[0])
dataloader1 = DataLoader(dataset1, batch_size=BATCH_SIZE, shuffle=False,collate_fn= dataset1.__collate_fn__,drop_last=True)
dataloader1

# %% [markdown]
# # STAGE 1

# %%
class Encoder(nn.Module):
    def __init__(self,dim_in) :
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv1d(in_channels=dim_in, out_channels=128, kernel_size=4, stride=2,padding=1),
            nn.Tanh(),
            nn.Dropout(p=0.1,inplace=True),
            nn.Conv1d(in_channels=128, out_channels=64, kernel_size=4, stride=2,padding=1),
            nn.Tanh(),
            nn.Dropout(p=0.1,inplace=True),
            nn.Conv1d(in_channels=64, out_channels=64, kernel_size=5, stride=3,padding=1),
            nn.Tanh()
        )
        
    def forward(self,x) :
        return self.network(x)
        

class Decoder(nn.Module):
    def __init__(self,dim_out) :
        super().__init__()
        self.network = nn.Sequential(
            nn.ConvTranspose1d(in_channels=64, out_channels=64, kernel_size=5, stride=3,padding=1),
            nn.Tanh(),
            nn.Dropout(p=0.1,inplace=True),
            nn.ConvTranspose1d(in_channels=64, out_channels=128, kernel_size=4, stride=2,padding=1),
            nn.Tanh(),
            nn.Dropout(p=0.1,inplace=True),
            nn.ConvTranspose1d(in_channels=128, out_channels=dim_out, kernel_size=4, stride=2,padding=1),
            nn.Tanh()
        )
        
    def forward(self,x) :
        return self.network(x)

class Discriminator(nn.Module):
    def __init__(self,dim_in) :
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv1d(in_channels=dim_in, out_channels=128, kernel_size=4, stride=2,padding=1),
            nn.Tanh(),
            nn.Dropout(p=0.1,inplace=True),
            nn.Conv1d(in_channels=128, out_channels=64, kernel_size=4, stride=2,padding=1),
            nn.Tanh(),
            nn.Dropout(p=0.1,inplace=True),
            nn.Conv1d(in_channels=64, out_channels=64, kernel_size=5, stride=3,padding=1),
            nn.Tanh()
            
        )
        
        self.fc = nn.Sequential(
            nn.Linear(in_features=64, out_features=64),
            nn.Sigmoid()
        )
        
    def forward(self,x) :
        x = self.network(x)
        x = torch.movedim(x,1,2)
        x = self.fc(x)
        x = torch.movedim(x,1,2)
        x = np.where(x >= 0.5,1.,0.)
        return torch.tensor(x,dtype=torch.float32)

# %%
def measure_similarity(H,M):
    H = H.detach().numpy()
    M = M.detach().numpy()
   
    tmp = np.exp(-1 * (-2 * (M.T@H) + np.sum(M**2,axis=0)[:, np.newaxis]  + np.sum(H**2,axis=1)[:, np.newaxis]))
    sum_tmp = np.sum(tmp,axis=0)
    C = tmp / sum_tmp  
    C = np.where(C.T == np.max(C.T,axis=0),1.,0.).T
    return torch.tensor(C,dtype=torch.float32) # DIM_M * DIM_T2


def calcule_loss_reconstruction(DIM_N,DIM_T,DIM_C,X,X_reconstruit):
    loss =  ( 1 / (DIM_N * DIM_T * DIM_C) ) * torch.sum(torch.pow(X_reconstruit - X,2)) # cout loss reconstruction
    return loss.clone().detach().requires_grad_(True) # torch.tensor(loss,requires_grad=True) 



def calcule_loss_m(DIM_N,DIM_T2,DIM_D,X,H,M):
    H2 = H.clone().detach() # avec stop gradient
    H2.requires_grad = False
    Z = np.argmin(H.detach().numpy()-M.detach().numpy(),axis=1)
    Z2 = np.argmin(H2-M,axis=1) # avec stop gradient
    Z2.requires_grad = False
    loss = ( 1 / (DIM_N * DIM_T2 * DIM_D) ) * torch.sum(torch.sum( torch.pow(H2-Z,2) + torch.pow(H-Z2,2)  ))
    return loss.clone().detach().requires_grad_(True) # torch.tensor(loss,requires_grad=True) 

  
def calcule_loss_d(DIM_N,DIM_T2,DATA_D,DATA_D_reconstruit) :
    torch_zero = torch.zeros_like(DATA_D)
    loss = ( 1 / (DIM_N * DIM_T2) ) * torch.sum(torch.sum(torch.maximum(torch_zero,1-DATA_D) + torch.maximum(torch_zero,1+DATA_D_reconstruit)))
    return loss.clone().detach().requires_grad_(True) # torch.tensor(loss,requires_grad=True) 


def calcule_loss(loss_REC,loss_M,DATA_D_reconstruit,DIM_N,DIM_T2,lambd,gamma):
    loss = loss_REC + lambd * loss_M - (gamma / (DIM_N * DIM_T2) ) * torch.sum(DATA_D_reconstruit)
    return loss.clone().detach().requires_grad_(True) # torch.tensor(loss,requires_grad=True)

# %%
def calcule_mse(DIM_N,DIM_H,DIM_C,y,y_pred):
    return ( 1 / DIM_N * DIM_H * DIM_C ) * torch.nn.functional.mse_loss(y_pred,y)

def calcule_mae(DIM_N,DIM_H,DIM_C,y,y_pred):
    return ( 1 / DIM_N * DIM_H * DIM_C ) * torch.nn.functional.l1_loss(y_pred,y)

# %%
# Stage 1

# %%
# mse = calcule_mse(DIM_N,DIM_H,DIM_C,y,y_pred)
# mae = calcule_mae(DIM_N,DIM_H,DIM_C,y,y_pred)

# %%
def train_stage_1(dataloader,epochs) :
    
    DIM_C = dataloader.dataset.data.shape[1] # Nombre de variable d'une serie chronologique
    DIM_D = 64 # Nombre de variable d'une serie chronologique apres encodeur ( taille couche sortie encodeur)
    DIM_N = len(dataloader.dataset.data) - dataloader.dataset.DIM_T - dataloader.dataset.DIM_H + 1 # Nombre de segment de longeur T
    DIM_M = 16 # Taille de la banque de mémoire ( voir papier taille 16)
    lambd = 0.5
    gamma = 0.5
     
    encoder = Encoder(DIM_C)
    decoder = Decoder(DIM_C)
    discriminator = Discriminator(DIM_C)
    
    opt_encoder = torch.optim.Adam(encoder.parameters(), lr=0.0001)
    opt_decoder = torch.optim.Adam(decoder.parameters(), lr=0.0001)
    opt_discriminator = torch.optim.Adam(discriminator.parameters(), lr=0.0001)
    
    DATA_M = torch.rand((DIM_D,DIM_M),dtype=torch.float32)# Banque de mémoire :  DIM_D X DIM_M
    
    for epoch in epochs :
        for e,(X,Y) in enumerate(dataloader) :
            
            opt_encoder.zero_grad()
            opt_decoder.zero_grad()
            opt_discriminator.zero_grad()
            
            # (1)             
            DATA_X = torch.movedim(X,1,2) # Data : BATCH_SIZE X DIM_C X DIM_T
            DATA_H = encoder(DATA_X) # Data Encoder : BATCH_SIZE X DIM_D X DIM_T2
            DATA_C = measure_similarity(DATA_H,DATA_M) # Matrice similarity : BATCH_SIZE * DIM_M * DIM_T2
            DIM_T2 =  DATA_H.shape[2] # Longeur d'une serie chronologique apres convolution T2 < T à cause convolution et stride suprérieur à 1
            
            DATA_H_reconstruit = (DATA_M @ DATA_C) # Data Encoder : BATCH_SIZE X DIM_D X DIM_T2
            DATA_X_reconstruit = decoder(DATA_H_reconstruit) # Data reconstruit : BATCH_SIZE X DIM_C X DIM_T
            loss_REC = calcule_loss_reconstruction(DIM_N,DIM_T,DIM_C,DATA_X.clone().detach(),DATA_X_reconstruit.clone().detach()) # cout loss reconstruction
            loss_M =  calcule_loss_m(DIM_N,DIM_T2,DIM_D,DATA_X,DATA_H,DATA_M) # cout loss m
            DATA_D = discriminator(DATA_X)  # : BATCH_SIZE X DIM_D X DIM_T2
            DATA_D_reconstruit = discriminator(DATA_X_reconstruit) #  : BATCH_SIZE X DIM_D X DIM_T2
            
            if e % 2 == 0 :
                # (3)                
                loss_D = calcule_loss_d(DIM_N,DIM_T2,DATA_D,DATA_D_reconstruit)
                loss_D.backward()
                print('loss_D : ', loss_D)
            else :
                # (4)  
                loss = calcule_loss(loss_REC,loss_M,DATA_D_reconstruit,DIM_N,DIM_T2,lambd,gamma)
                loss.backward()
                print('loss : ', loss)

#             print('loss_REC : ',loss_REC)
#             print('loss_M : ', loss_M)
#             print('loss_D : ', loss_D)
            
            

            opt_encoder.step()
            opt_decoder.step()
            opt_discriminator.step()
                
    return encoder,decoder, DATA_M

# %%
encoder,decoder, DATA_M = train_stage_1(dataloader1,epochs=range(1))
# Out:
# loss_D :  tensor(0.0578, requires_grad=True)
# loss :  tensor(1088.4798, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(1184.0475, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1213.0448, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1209.7692, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1189.1252, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(1132.5608, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1164.1729, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1161.1810, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(1125.0885, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1132.5251, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(1125.2104, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(1130.6739, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0577, requires_grad=True)
# loss :  tensor(1136.4721, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(1107.6809, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1037.2001, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1009.8045, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1025.3502, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1064.4895, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0577, requires_grad=True)
# loss :  tensor(1079.6944, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0578, requires_grad=True)
# loss :  tensor(1119.7535, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0577, requires_grad=True)
# loss :  tensor(1104.8378, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(1012.1901, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1022.0292, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1023.1078, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1021.7776, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1062.1399, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(995.2230, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(964.6095, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(1014.8131, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0575, requires_grad=True)
# loss :  tensor(1035.4725, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(1084.4179, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(1049.4708, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(1046.2047, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0576, requires_grad=True)
# loss :  tensor(
dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(10436.6202, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(9372.0073, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(9779.0939, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(10878.6837, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(11001.5678, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(12692.5998, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(13977.5619, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(14984.1450, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(14254.7058, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(13618.0189, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(14393.6825, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0579, requires_grad=True)
# loss :  tensor(13398.6617, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(13084.4391, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(12849.2860, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(13495.6428, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(12185.5480, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(10802.4948, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0579, requires_grad=True)
# loss :  tensor(11192.0173, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(11307.5051, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(11457.9593, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(13415.2321, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0579, requires_grad=True)
# loss :  tensor(17073.8569, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(15862.4563, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0579, requires_grad=True)
# loss :  tensor(13239.2649, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(11896.7063, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(12572.4352, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0579, requires_grad=True)
# loss :  tensor(12988.3529, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0579, requires_grad=True)
# loss :  tensor(12024.5924, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0579, requires_grad=True)
# loss :  tensor(11838.3202, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(12404.5888, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(12530.0970, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(12029.1461, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(11433.0594, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(11328.0246, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(10647.1043, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(10274.9723, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(9481.3081, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(8668.7144, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(8123.8928, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(8005.7754, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0583, requires_grad=True)
# loss :  tensor(7837.3768, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(7462.8533, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(7143.1290, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(6882.0143, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(7470.5717, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(7725.5220, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0583, requires_grad=True)
# loss :  tensor(7251.8169, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(7135.6585, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(8285.6766, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(9082.7068, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(8051.3680, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(6165.3398, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(6630.0323, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(7417.5142, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0580, requires_grad=True)
# loss :  tensor(7138.6284, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0583, requires_grad=True)
# loss :  tensor(6374.3946, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0583, requires_grad=True)
# loss :  tensor(4860.8974, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0583, requires_grad=True)
# loss :  tensor(3829.2002, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0583, requires_grad=True)
# loss :  tensor(4720.2950, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(6151.5206, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(6705.5723, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0583, requires_grad=True)
# loss :  tensor(7253.4464, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(7837.8498, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(8709.7106, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(8239.5963, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(7082.7801, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0583, requires_grad=True)
# loss :  tensor(6675.1265, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(6053.5110, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(5591.4630, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(5393.8866, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(5428.7861, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0583, requires_grad=True)
# loss :  tensor(5604.2472, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0582, requires_grad=True)
# loss :  tensor(4568.3434, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(3369.7154, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0583, requires_grad=True)
# loss :  tensor(2878.6627, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0585, requires_grad=True)
# loss :  tensor(2854.2747, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(3410.6903, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0584, requires_grad=True)
# loss :  tensor(2984.3363, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0584, requires_grad=True)
# loss :  tensor(2942.0224, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(3404.9550, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0585, requires_grad=True)
# loss :  tensor(3506.5346, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0584, requires_grad=True)
# loss :  tensor(3294.1754, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0585, requires_grad=True)
# loss :  tensor(3044.2575, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0585, requires_grad=True)
# loss :  tensor(2966.9840, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(3201.3761, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0585, requires_grad=True)
# loss :  tensor(3328.7621, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0585, requires_grad=True)
# loss :  tensor(3521.2249, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(3582.9652, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0585, requires_grad=True)
# loss :  tensor(3266.0186, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0585, requires_grad=True)
# loss :  tensor(2997.4225, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0588, requires_grad=True)
# loss :  tensor(2803.1757, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0587, requires_grad=True)
# loss :  tensor(2889.6872, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(2969.7669, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(2902.6883, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(2853.1947, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(2722.1033, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0587, requires_grad=True)
# loss :  tensor(2708.0682, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0587, requires_grad=True)
# loss :  tensor(2689.6697, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0587, requires_grad=True)
# loss :  tensor(2706.0225, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0587, requires_grad=True)
# loss :  tensor(2642.8374, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0587, requires_grad=True)
# loss :  tensor(2662.0834, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0587, requires_grad=True)
# loss :  tensor(2840.5496, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0587, requires_grad=True)
# loss :  tensor(2725.4415, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0583, requires_grad=True)
# loss :  tensor(2477.3592, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0584, requires_grad=True)
# loss :  tensor(2659.1215, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0587, requires_grad=True)
# loss :  tensor(2859.2935, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0585, requires_grad=True)
# loss :  tensor(2854.6989, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(2802.8738, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0588, requires_grad=True)
# loss :  tensor(2853.2550, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(2961.0140, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(2821.8867, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(1709.8689, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0581, requires_grad=True)
# loss :  tensor(1990.0544, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0587, requires_grad=True)
# loss :  tensor(2772.9976, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0586, requires_grad=True)
# loss :  tensor(2853.1349, dtype=torch.float64, requires_grad=True)
# loss_D :  tensor(0.0585, requires_grad=True)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-122-3116dcb7df3d> in <module>
# ----> 1 encoder,decoder, DATA_M = train_stage_1(dataloader1,epochs=range(1))
#
# <ipython-input-121-705d061607cc> in train_stage_1(dataloader, epochs)
#      19
#      20     for epoch in epochs :
# ---> 21         for e,(X,Y) in enumerate(dataloader) :
#      22
#      23             opt_encoder.zero_grad()
#
# ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     679                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680                 self._reset()  # type: ignore[call-arg]
# --> 681             data = self._next_data()
#     682             self._num_yielded += 1
#     683             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~\anaconda3\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     719     def _next_data(self):
#     720         index = self._next_index()  # may raise StopIteration
# --> 721         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     722         if self._pin_memory:
#     723             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# ~\anaconda3\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
# ---> 52         return self.collate_fn(data)
#
# <ipython-input-112-280d6939e6b2> in __collate_fn__(self, batch)
#      16
#      17         X = torch.stack([ torch.tensor(item[0],dtype=torch.float32) for item in batch])
# ---> 18         y = torch.stack([ torch.tensor(item[1],dtype=torch.float32) for item in batch]) #Produit un élément en plus
#      19
#      20         return (X,y)
#
# RuntimeError: stack expects each tensor to be equal size, but got [96, 370] at entry 0 and [95, 370] at entry 1

# %% [markdown]
# # STAGE 2

# %%
class Predictor(nn.Module):
    def __init__(self,dim_in) :
        super().__init__()
        self.network = nn.Sequential(
            torch.nn.LSTM(input_size=dim_in , hidden_size=128, num_layers=8, dropout=0.5 )
        )
      
    def forward(self,x) :
        x,_ = self.network(x)
        x = torch.nn.Softmax()(x)
        return torch.tensor(x,dtype=torch.float32)

# %%
def calcule_loss_pred(DIM_T2,DIM_HH,DATA_C_reconstruit,DATA_CC):
    loss = (1 / (DIM_T2 + DIM_HH)) * torch.nn.functional.binary_cross_entropy(DATA_CC, DATA_C_reconstruit)
    return loss

# %%
BATCH_SIZE = 64
DIM_TT = 96 # Longeur d'une serie chronologique stage 2
DIM_H = [96, 192, 336, 720]# Nombre de valeur à prédire pour une serie chronologique

dataset2  = DatasetLd(path='../data/LD2011_2014/LD2011_2014.pkl',DIM_T=DIM_TT,DIM_H=DIM_H[0])
dataloader2 = DataLoader(dataset2, batch_size=BATCH_SIZE, shuffle=False,collate_fn= dataset2.__collate_fn__)
dataloader2

# %%
DIM_C = dataloader2.dataset.data.shape[1] # Nombre de variable d'une serie chronologique
encoder = Encoder(DIM_C)
decoder = Decoder(DIM_C)
discriminator = Discriminator(DIM_C)
DATA_M = torch.rand((64,16),dtype=torch.float32)# Banque de mémoire :  DIM_D X DIM_M
    
list_model = [encoder,decoder,discriminator]
for model in list_model :
    for param in model.parameters() :
        param.requires_grad = False

# %%
from math import ceil

def train_stage_2(encoder,decoder,DATA_M,dataloader,epochs) :
    
    DIM_C = dataloader.dataset.data.shape[1] # Nombre de variable d'une serie chronologique
    DIM_D = 64 # Nombre de variable d'une serie chronologique apres encodeur ( taille couche sortie encodeur)
    DIM_N = len(dataloader.dataset.data) - dataloader.dataset.DIM_T - dataloader.dataset.DIM_H + 1 # Nombre de segment de longeur T
    DIM_M = 16 # Taille de la banque de mémoire ( voir papier taille 16)

     
    predictor = Predictor(DIM_M)

    opt_predictor = torch.optim.AdamW(predictor.parameters(), lr=0.0001)

    for epoch in epochs :
        for X,Y in dataloader :
         
            opt_predictor.zero_grad()
            
            # (1)             
            DATA_X = torch.movedim(X,1,2) # Data : BATCH_SIZE X DIM_C X DIM_T
            DATA_H = encoder(DATA_X) # Data Encoder : BATCH_SIZE X DIM_D X DIM_T2
            DATA_C = measure_similarity(DATA_H,DATA_M) # Matrice similarity : BATCH_SIZE * DIM_M * DIM_T2
            DIM_T2 =  DATA_H.shape[2] # Longeur d'une serie chronologique apres convolution T2 < T à cause convolution et stride suprérieur à 1
            
            
            # (5)            
            DIM_CC = ceil(DIM_T2*(dataloader.dataset.DIM_T + dataloader.dataset.DIM_H) / dataloader.dataset.DIM_T)
            DIM_HH = ceil(DIM_T2*dataloader.dataset.DIM_H / dataloader.dataset.DIM_T)
        
            DATA_C = torch.movedim(DATA_C,1,2) # Data : BATCH_SIZE X DIM_T2 X DIM_M
            DATA_C_reconstruit = predictor(DATA_C)
            
            # (6) 
            DATA_X_Y = torch.cat((X,Y),dim=0)
            DATA_X_Y = encoder(DATA_X_Y)
            DATA_CC = DATA_M @ DATA_X_Y
            
            # (7) 
            loss_P = calcule_loss_pred(DIM_T2,DIM_HH,DATA_C_reconstruit,DATA_CC)
            loss_P.backward()
        
            print('loss_P : ',loss_P)
            print()

            opt_predictor.step()
                
    return predictor

# %%
train_stage_2(encoder,decoder,DATA_M,dataloader2,epochs=range(1))
# Out:
# torch.Size([64, 8, 128])
# <ipython-input-327-287f5368d715>:11: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = torch.nn.Softmax()(x)
# <ipython-input-327-287f5368d715>:12: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x,dtype=torch.float32)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-332-5102e04f63e3> in <module>
# ----> 1 train_stage_2(encoder,decoder,DATA_M,dataloader2,epochs=range(1))
#
# <ipython-input-331-febd45cbfc7a> in train_stage_2(encoder, decoder, DATA_M, dataloader, epochs)
#      34             # (6)
#      35             DATA_X_Y = torch.cat((X,Y),dim=0)
# ---> 36             DATA_X_Y = encoder(DATA_X_Y)
#      37             DATA_CC = DATA_M @ DATA_X_Y
#      38
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-265-6594900824da> in forward(self, x)
#      14
#      15     def forward(self,x) :
# ---> 16         return self.network(x)
#      17
#      18
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\conv.py in forward(self, input)
#     305
#     306     def forward(self, input: Tensor) -> Tensor:
# --> 307         return self._conv_forward(input, self.weight, self.bias)
#     308
#     309
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\conv.py in _conv_forward(self, input, weight, bias)
#     301                             weight, bias, self.stride,
#     302                             _single(0), self.dilation, self.groups)
# --> 303         return F.conv1d(input, weight, bias, self.stride,
#     304                         self.padding, self.dilation, self.groups)
#     305
#
# RuntimeError: Given groups=1, weight of size [128, 370, 4], expected input[128, 96, 370] to have 370 channels, but got 96 channels instead

# %% [markdown]
# # STAGE 3

# %%
def inference(X,encoder,decoder,DATA_M) :
    pass
